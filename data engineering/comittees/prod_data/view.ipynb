# %%
import pandas as pd
# Out:
# /Users/mats_dodd/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
trans = pd.read_csv('../prod_data/transactions.csv')
trans.dropna()
# Out:
#                display_name transaction_date disclosure_date ticker  \
# 0            Rep. Susie Lee       2020-02-24      2020-04-28    BHC
# 1            Rep. Susie Lee       2020-03-06      2020-04-28    BAH
# 2            Rep. Susie Lee       2020-03-23      2020-04-28    BYD
# 3            Rep. Susie Lee       2020-02-04      2020-04-28   CTLT
# 4            Rep. Susie Lee       2020-03-18      2020-04-28   CBRE
# ...                     ...              ...             ...    ...
# 15678     Rep. Lois Frankel       2023-03-22      2023-04-28    PGR
# 15679     Rep. Lois Frankel       2023-04-05      2023-04-28     CI
# 15681  Rep. Earl Blumenauer       2023-02-15      2023-03-09    NWN
# 15682     Rep. Dwight Evans       2023-02-28      2023-03-09    CSX
# 15683     Rep. Dwight Evans       2023-02-28      2023-03-09    CRM
#
#                              asset_description          type  \
# 0                 Bausch Health Companies Inc.      purchase
# ...

# %%
trans[trans['display_name'].isna()]
# Out:
#       display_name transaction_date disclosure_date ticker  \
# 613            NaN       2019-12-19      2020-01-15   AAWW
# 770            NaN       2020-03-25      2020-06-01     BA
# 771            NaN       2020-03-25      2020-06-01    CIM
# 772            NaN       2020-03-26      2020-06-01    FEI
# 773            NaN       2020-03-25      2020-06-01    PSX
# ...            ...              ...             ...    ...
# 15561          NaN       2023-05-01      2023-05-09  STRNX
# 15650          NaN       2023-04-10      2023-05-02     GS
# 15651          NaN       2023-04-10      2023-05-02   MSFT
# 15652          NaN       2023-04-10      2023-05-02    DLB
# 15653          NaN       2023-04-10      2023-05-02  OBMCX
#
#                                        asset_description          type  \
# 613                         Atlas Air Worldwide Holdings      purchase
# 770                                       Boeing Company      purchase
# ...

# %%
trans
# Out:
#                display_name transaction_date disclosure_date ticker  \
# 0            Rep. Susie Lee       2020-02-24      2020-04-28    BHC
# 1            Rep. Susie Lee       2020-03-06      2020-04-28    BAH
# 2            Rep. Susie Lee       2020-03-23      2020-04-28    BYD
# 3            Rep. Susie Lee       2020-02-04      2020-04-28   CTLT
# 4            Rep. Susie Lee       2020-03-18      2020-04-28   CBRE
# ...                     ...              ...             ...    ...
# 15679     Rep. Lois Frankel       2023-04-05      2023-04-28     CI
# 15680     Rep. Lois Frankel       2023-03-16      2023-04-28   ULTA
# 15681  Rep. Earl Blumenauer       2023-02-15      2023-03-09    NWN
# 15682     Rep. Dwight Evans       2023-02-28      2023-03-09    CSX
# 15683     Rep. Dwight Evans       2023-02-28      2023-03-09    CRM
#
#                              asset_description          type  \
# 0                 Bausch Health Companies Inc.      purchase
# ...
