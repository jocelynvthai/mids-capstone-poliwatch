# %%
# Install the required libraries if you haven't already
# !pip install torch transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from transformers import AutoModel, AutoTokenizer
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def tokenize_text_data(text, tokenizer = False):
  tokenized_text = tokenizer(text, return_tensors="pt")['input_ids']
  return tokenized_text


def fetch_embeddings_for_text_data(tokenized_text, model = False):
  with torch.no_grad():
    embeddings = model(tokenized_text)['last_hidden_state'].mean(dim=1).numpy()
  return embeddings


def calculate_cosine_similarity(text_embedding_one, text_embedding_two):
  return cosine_similarity(text_embedding_one, text_embedding_two)[0][0]



def orchestrate(df, col1, col2):

  df[col1] = df[col1].astype(str)
  df[col2] = df[col2].astype(str)
  model_name = "bert-base-uncased"  # You can change the model as needed
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  model = AutoModel.from_pretrained(model_name)

  tokenizer_lambda = lambda x, y = tokenizer: tokenize_text_data(x, y)
  col1_tokenized = df[col1].apply(tokenizer_lambda)
  col2_tokenized = df[col2].apply(tokenizer_lambda)

  embeddings_lambda = lambda x, y = model: fetch_embeddings_for_text_data(x, y)
  col1_tokenized_embeddings = list(col1_tokenized.apply(embeddings_lambda))
  col2_tokenized_embeddings = list(col2_tokenized.apply(embeddings_lambda))

  semantic_similarities = [calculate_cosine_similarity(col1_tokenized_embeddings[i], col2_tokenized_embeddings[i]) for i in range(len(col1_tokenized_embeddings))]
  return semantic_similarities


def correlate(df, col1, col2, name = False):
  if name:
    df = df[df['Member'] == name]
  other_df = orchestrate(df[['Member', 'disclosure_date', 'transaction_date', col1, col2]], col1, col2)
  other_df = pd.Series(other_df).to_frame().reset_index()
  df = df.reset_index().merge(other_df, how = 'inner', on = 'index')
  return df.drop_duplicates()

# %% [markdown]
# # Transactions Link to Committees and Subcommittees

# %%
transactions = pd.read_csv('stacked_df.csv')
committees = pd.read_csv('committees.csv')
membership = pd.read_csv('membership.csv')
transactions.head()
# Out:
# /var/folders/x8/h5h7bn_54gncqkrgpt4wmclc0000gn/T/ipykernel_10702/282432529.py:1: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   transactions = pd.read_csv('stacked_df.csv')
#   disclosure_date transaction_date  owner ticker  \
# 0      2020-04-28       2020-02-24  joint    BHC
# 1      2020-04-28       2020-03-06  joint    BAH
# 2      2020-04-28       2020-03-23  joint    BYD
# 3      2020-04-28       2020-02-04  joint   CTLT
# 4      2020-04-28       2020-03-18  joint   CBRE
#
#                          asset_description          type            amount  \
# 0             Bausch Health Companies Inc.      purchase  $1,001 - $15,000
# 1  Booz Allen Hamilton Holding Corporation     sale_full  $1,001 - $15,000
# 2                  Boyd Gaming Corporation     sale_full  $1,001 - $15,000
# 3                           Catalent, Inc.      purchase  $1,001 - $15,000
# 4      CBRE Group Inc Common Stock Class A  sale_partial  $1,001 - $15,000
#
#     member_x district state  ... HSSM22  SSCM33 SSCM34 SSCM35 SSCM36  SSCM37  \
# 0  susie lee     NV03    NV  ...    NaN     NaN    NaN    NaN    NaN     NaN
# 1  susie lee     NV03    NV  ...    NaN     NaN    NaN    NaN    NaN     NaN
# 2  susie lee     NV03    NV  ...    NaN     NaN    NaN    NaN    NaN     NaN
# 3  susie lee     NV03    NV  ...    NaN     NaN    NaN    NaN    NaN     NaN
# 4  susie lee     NV03    NV  ...    NaN     NaN    NaN    NaN    NaN     NaN
#
#    SSCM38 SSCM39  SSJU27 SSJU28
# 0     NaN    NaN     NaN    NaN
# 1     NaN    NaN     NaN    NaN
# 2     NaN    NaN     NaN    NaN
# 3     NaN    NaN     NaN    NaN
# 4     NaN    NaN     NaN    NaN
#
# [5 rows x 282 columns]

# %%
transactions_cols_list = ['member_x', 'disclosure_date', 'transaction_date', 'owner', 'ticker', 'asset_description', 'type', 'amount', 'industry', 'sector']
transactions = transactions[transactions_cols_list]
transactions = transactions.rename(columns = {'member_x': 'Member'})
transactions
# Out:
#                 Member disclosure_date transaction_date  owner ticker  \
# 0            susie lee      2020-04-28       2020-02-24  joint    BHC
# 1            susie lee      2020-04-28       2020-03-06  joint    BAH
# 2            susie lee      2020-04-28       2020-03-23  joint    BYD
# 3            susie lee      2020-04-28       2020-02-04  joint   CTLT
# 4            susie lee      2020-04-28       2020-03-18  joint   CBRE
# ...                ...             ...              ...    ...    ...
# 15679     lois frankel      2023-04-28       2023-04-05    NaN     CI
# 15680     lois frankel      2023-04-28       2023-03-16    NaN   ULTA
# 15681  earl blumenauer      2023-03-09       2023-02-15   self    NWN
# 15682     dwight evans      2023-03-09       2023-02-28    NaN    CSX
# 15683     dwight evans      2023-03-09       2023-02-28    NaN    CRM
#
#                              asset_description          type  \
# 0                 Bausch Health Companies Inc.      purchase
# 1      Booz Allen Hamilton Holding Corporation     sale_full
# 2                      Boyd Gaming Corporation     sale_full
# 3                               Catalent, Inc.      purchase
# 4          CBRE Group Inc Common Stock Class A  sale_partial
# ...                                        ...           ...
# 15679                          The Cigna Group      purchase
# 15680                          Ulta Beauty inc  sale_partial
# 15681        Northwest Natural Holding Company      purchase
# 15682                          CSX Corporation     sale_full
# 15683                           Salesforce Inc     sale_full
#
#                  amount                                    industry  \
# 0      $1,001 - $15,000           Pharmaceuticals and Biotechnology
# 1      $1,001 - $15,000                       Professional Services
# 2      $1,001 - $15,000                        Movies/Entertainment
# 3      $1,001 - $15,000  Biotechnology: Pharmaceutical Preparations
# 4      $1,001 - $15,000                                 Real Estate
# ...                 ...                                         ...
# 15679  $1,001 - $15,000                        Medical Specialities
# 15680  $1,001 - $15,000                                         NaN
# 15681  $1,001 - $15,000                        Oil/Gas Transmission
# 15682  $1,001 - $15,000                                   Railroads
# 15683  $1,001 - $15,000     Computer Software: Prepackaged Software
#
#                        sector
# 0                 Health Care
# 1           Consumer Services
# 2      Consumer Discretionary
# 3                 Health Care
# 4                     Finance
# ...                       ...
# 15679             Health Care
# 15680                     NaN
# 15681        Public Utilities
# 15682          Transportation
# 15683              Technology
#
# [15684 rows x 10 columns]

# %%
committees.head()
# Out:
#                         Committee Comittee_code  \
# 0  House Committee on Agriculture          HSAG
# 1  House Committee on Agriculture          HSAG
# 2  House Committee on Agriculture          HSAG
# 3  House Committee on Agriculture          HSAG
# 4  House Committee on Agriculture          HSAG
#
#                                         Subcommittee Subcommittee_code
# 0                                           Forestry            HSAG15
# 1  Commodity Markets, Digital Assets, and Rural D...            HSAG22
# 2  General Farm Commodities, Risk Management, and...            HSAG16
# 3                      Livestock, Dairy, and Poultry            HSAG29
# 4          Conservation, Research, and Biotechnology            HSAG14

# %%
membership['Member_name'] = membership['Member_name'].str.lower()
membership.head()
# Out:
#   Comittee_code          Member_name
# 0          HSII      bruce westerman
# 1          HSII     raúl m. grijalva
# 2          HSII         doug lamborn
# 3          HSII  grace f. napolitano
# 4          HSII    robert j. wittman

# %%
transactions_link_committees = transactions.merge(membership, how = 'inner', left_on = 'Member', right_on = 'Member_name')
transactions_link_committees = transactions_link_committees.merge(committees, how = 'inner', on = 'Comittee_code')
transactions_link_committees.head()
# Out:
#       Member disclosure_date transaction_date  owner ticker  \
# 0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1  susie lee      2020-04-28       2020-02-24  joint    BHC
# 2  susie lee      2020-04-28       2020-02-24  joint    BHC
# 3  susie lee      2020-04-28       2020-02-24  joint    BHC
# 4  susie lee      2020-04-28       2020-02-24  joint    BHC
#
#               asset_description      type            amount  \
# 0  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 1  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 2  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 3  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 4  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
#
#                             industry       sector Comittee_code Member_name  \
# 0  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 1  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 2  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 3  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 4  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
#
#                               Committee                   Subcommittee  \
# 0  House Committee on Natural Resources   Energy and Mineral Resources
# 1  House Committee on Natural Resources                  Federal Lands
# 2  House Committee on Natural Resources  Water, Wildlife and Fisheries
# 3  House Committee on Natural Resources     Indian and Insular Affairs
# 4  House Committee on Natural Resources   Oversight and Investigations
#
#   Subcommittee_code
# 0            HSII06
# 1            HSII10
# 2            HSII13
# 3            HSII24
# 4            HSII15

# %% [markdown]
# ## Transformations to obtain company, committee, and subcomittee descriptions to enhance the semantic contextual correlation capacity of the BERT transformer model

# %%
### Obtain all distinct asset descriptions

asset_descriptions = transactions_link_committees['asset_description'].value_counts().to_frame().reset_index()[['index']].drop_duplicates()
asset_descriptions.to_csv('asset_descriptions.csv')

# %%
### Obtain all distinct committees

commmittees = transactions_link_committees['Committee'].value_counts().to_frame().reset_index()[['index']].drop_duplicates()
commmittees.to_csv('committee.csv')

# %%
### Obtain all distinct subcommittees

subcommittees = transactions_link_committees['Subcommittee'].value_counts().to_frame().reset_index()[['index']].drop_duplicates()
subcommittees.to_csv('subcommittee.csv')

# %%
### Obtain all distinct industries

industries = transactions_link_committees['industry'].value_counts().to_frame().reset_index()[['index']].drop_duplicates()
industries.to_csv('industry.csv')

# %%
### Merge committees

committees_enriched = pd.read_csv('comittee_enriched.csv')
transactions_link_committees = transactions_link_committees.merge(committees_enriched, how = 'inner', on = 'Committee')
transactions_link_committees = transactions_link_committees.rename(columns = {
    'Descriptions': 'committee_description'
})
transactions_link_committees = transactions_link_committees.drop(columns = ['Unnamed: 0'])
transactions_link_committees.head()
# Out:
#       Member disclosure_date transaction_date  owner ticker  \
# 0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1  susie lee      2020-04-28       2020-02-24  joint    BHC
# 2  susie lee      2020-04-28       2020-02-24  joint    BHC
# 3  susie lee      2020-04-28       2020-02-24  joint    BHC
# 4  susie lee      2020-04-28       2020-02-24  joint    BHC
#
#               asset_description      type            amount  \
# 0  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 1  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 2  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 3  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
# 4  Bausch Health Companies Inc.  purchase  $1,001 - $15,000
#
#                             industry       sector Comittee_code Member_name  \
# 0  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 1  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 2  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 3  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 4  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
#
#                               Committee                   Subcommittee  \
# 0  House Committee on Natural Resources   Energy and Mineral Resources
# 1  House Committee on Natural Resources                  Federal Lands
# 2  House Committee on Natural Resources  Water, Wildlife and Fisheries
# 3  House Committee on Natural Resources     Indian and Insular Affairs
# 4  House Committee on Natural Resources   Oversight and Investigations
#
#   Subcommittee_code                              committee_description
# 0            HSII06  Manages federal lands, oversees energy and min...
# 1            HSII10  Manages federal lands, oversees energy and min...
# 2            HSII13  Manages federal lands, oversees energy and min...
# 3            HSII24  Manages federal lands, oversees energy and min...
# 4            HSII15  Manages federal lands, oversees energy and min...

# %%
### Merge subcommittees
subcommittees_enriched = pd.read_csv('subcommittee_enriched.csv')
transactions_link_committees = transactions_link_committees.merge(subcommittees_enriched, how = 'inner', left_on = 'Subcommittee', right_on = 'index')
transactions_link_committees = transactions_link_committees.rename(columns = {
    'Description': 'subcommittee_description'
})
transactions_link_committees = transactions_link_committees.drop(columns = ['Unnamed: 0', 'index'])
transactions_link_committees.head()
# Out:
#       Member disclosure_date transaction_date  owner ticker  \
# 0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1  susie lee      2020-04-28       2020-03-06  joint    BAH
# 2  susie lee      2020-04-28       2020-03-23  joint    BYD
# 3  susie lee      2020-04-28       2020-02-04  joint   CTLT
# 4  susie lee      2020-04-28       2020-03-18  joint   CBRE
#
#                          asset_description          type            amount  \
# 0             Bausch Health Companies Inc.      purchase  $1,001 - $15,000
# 1  Booz Allen Hamilton Holding Corporation     sale_full  $1,001 - $15,000
# 2                  Boyd Gaming Corporation     sale_full  $1,001 - $15,000
# 3                           Catalent, Inc.      purchase  $1,001 - $15,000
# 4      CBRE Group Inc Common Stock Class A  sale_partial  $1,001 - $15,000
#
#                                      industry                  sector  \
# 0           Pharmaceuticals and Biotechnology             Health Care
# 1                       Professional Services       Consumer Services
# 2                        Movies/Entertainment  Consumer Discretionary
# 3  Biotechnology: Pharmaceutical Preparations             Health Care
# 4                                 Real Estate                 Finance
#
#   Comittee_code Member_name                             Committee  \
# 0          HSII   susie lee  House Committee on Natural Resources
# 1          HSII   susie lee  House Committee on Natural Resources
# 2          HSII   susie lee  House Committee on Natural Resources
# 3          HSII   susie lee  House Committee on Natural Resources
# 4          HSII   susie lee  House Committee on Natural Resources
#
#                    Subcommittee Subcommittee_code  \
# 0  Energy and Mineral Resources            HSII06
# 1  Energy and Mineral Resources            HSII06
# 2  Energy and Mineral Resources            HSII06
# 3  Energy and Mineral Resources            HSII06
# 4  Energy and Mineral Resources            HSII06
#
#                                committee_description  \
# 0  Manages federal lands, oversees energy and min...
# 1  Manages federal lands, oversees energy and min...
# 2  Manages federal lands, oversees energy and min...
# 3  Manages federal lands, oversees energy and min...
# 4  Manages federal lands, oversees energy and min...
#
#                             subcommittee_description
# 0  Addresses legislation concerning energy and mi...
# 1  Addresses legislation concerning energy and mi...
# 2  Addresses legislation concerning energy and mi...
# 3  Addresses legislation concerning energy and mi...
# 4  Addresses legislation concerning energy and mi...

# %%
### Merge industries
industry_enriched = pd.read_csv('industry_enriched.csv')
transactions_link_committees = transactions_link_committees.merge(industry_enriched, how = 'inner', left_on = 'industry', right_on = 'Industry')
transactions_link_committees = transactions_link_committees.drop(columns = ['Industry'])
transactions_link_committees = transactions_link_committees.rename(columns = {
    list(transactions_link_committees.columns)[-1]: 'industry_description'
})
transactions_link_committees.head()
# Out:
#       Member disclosure_date transaction_date  owner ticker  \
# 0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1  susie lee      2020-02-25       2020-01-06  joint    BHC
# 2  susie lee      2020-10-07       2020-08-27  joint    BHC
# 3  susie lee      2020-04-28       2020-02-24  joint    BHC
# 4  susie lee      2020-02-25       2020-01-06  joint    BHC
#
#               asset_description       type            amount  \
# 0  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 1  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 2  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 3  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 4  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
#
#                             industry       sector Comittee_code Member_name  \
# 0  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 1  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 2  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 3  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 4  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
#
#                               Committee                  Subcommittee  \
# 0  House Committee on Natural Resources  Energy and Mineral Resources
# 1  House Committee on Natural Resources  Energy and Mineral Resources
# 2  House Committee on Natural Resources  Energy and Mineral Resources
# 3  House Committee on Natural Resources                 Federal Lands
# 4  House Committee on Natural Resources                 Federal Lands
#
#   Subcommittee_code                              committee_description  \
# 0            HSII06  Manages federal lands, oversees energy and min...
# 1            HSII06  Manages federal lands, oversees energy and min...
# 2            HSII06  Manages federal lands, oversees energy and min...
# 3            HSII10  Manages federal lands, oversees energy and min...
# 4            HSII10  Manages federal lands, oversees energy and min...
#
#                             subcommittee_description  \
# 0  Addresses legislation concerning energy and mi...
# 1  Addresses legislation concerning energy and mi...
# 2  Addresses legislation concerning energy and mi...
# 3  Concerned with legislation and oversight relat...
# 4  Concerned with legislation and oversight relat...
#
#                                 industry_description
# 0  Companies involved in the production of pharma...
# 1  Companies involved in the production of pharma...
# 2  Companies involved in the production of pharma...
# 3  Companies involved in the production of pharma...
# 4  Companies involved in the production of pharma...

# %% [markdown]
# # Now, correlate the Industry with the Committees

# %%
industry_plus_committees = correlate(transactions_link_committees.head(20), 'industry_description', 'committee_description')
industry_plus_committees
# Out:
# <ipython-input-131-cae931bd611c>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col1] = df[col1].astype(str)
# <ipython-input-131-cae931bd611c>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col2] = df[col2].astype(str)
#     index     Member disclosure_date transaction_date  owner ticker  \
# 0       0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1       1  susie lee      2020-02-25       2020-01-06  joint    BHC
# 2       2  susie lee      2020-10-07       2020-08-27  joint    BHC
# 3       3  susie lee      2020-04-28       2020-02-24  joint    BHC
# 4       4  susie lee      2020-02-25       2020-01-06  joint    BHC
# 5       5  susie lee      2020-10-07       2020-08-27  joint    BHC
# 6       6  susie lee      2020-04-28       2020-02-24  joint    BHC
# 7       7  susie lee      2020-02-25       2020-01-06  joint    BHC
# 8       8  susie lee      2020-10-07       2020-08-27  joint    BHC
# 9       9  susie lee      2020-04-28       2020-02-24  joint    BHC
# 10     10  susie lee      2020-02-25       2020-01-06  joint    BHC
# 11     11  susie lee      2020-10-07       2020-08-27  joint    BHC
# 12     12  susie lee      2020-04-28       2020-02-24  joint    BHC
# 13     13  susie lee      2020-02-25       2020-01-06  joint    BHC
# 14     14  susie lee      2020-10-07       2020-08-27  joint    BHC
# 15     15  susie lee      2020-04-28       2020-02-24  joint    BHC
# 16     16  susie lee      2020-02-25       2020-01-06  joint    BHC
# 17     17  susie lee      2020-10-07       2020-08-27  joint    BHC
# 18     18  susie lee      2020-04-28       2020-02-24  joint    BHC
# 19     19  susie lee      2020-02-25       2020-01-06  joint    BHC
#
#                asset_description       type            amount  \
# 0   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 1   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 2   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 3   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 4   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 5   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 6   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 7   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 8   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 9   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 10  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 11  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 12  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 13  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 14  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 15  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 16  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 17  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 18  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 19  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
#
#                              industry       sector Comittee_code Member_name  \
# 0   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 1   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 2   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 3   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 4   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 5   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 6   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 7   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 8   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 9   Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 10  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 11  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 12  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 13  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 14  Pharmaceuticals and Biotechnology  Health Care          HSII   susie lee
# 15  Pharmaceuticals and Biotechnology  Health Care          HSAP   susie lee
# 16  Pharmaceuticals and Biotechnology  Health Care          HSAP   susie lee
# 17  Pharmaceuticals and Biotechnology  Health Care          HSAP   susie lee
# 18  Pharmaceuticals and Biotechnology  Health Care          HSAP   susie lee
# 19  Pharmaceuticals and Biotechnology  Health Care          HSAP   susie lee
#
#                                Committee  \
# 0   House Committee on Natural Resources
# 1   House Committee on Natural Resources
# 2   House Committee on Natural Resources
# 3   House Committee on Natural Resources
# 4   House Committee on Natural Resources
# 5   House Committee on Natural Resources
# 6   House Committee on Natural Resources
# 7   House Committee on Natural Resources
# 8   House Committee on Natural Resources
# 9   House Committee on Natural Resources
# 10  House Committee on Natural Resources
# 11  House Committee on Natural Resources
# 12  House Committee on Natural Resources
# 13  House Committee on Natural Resources
# 14  House Committee on Natural Resources
# 15     House Committee on Appropriations
# 16     House Committee on Appropriations
# 17     House Committee on Appropriations
# 18     House Committee on Appropriations
# 19     House Committee on Appropriations
#
#                                          Subcommittee Subcommittee_code  \
# 0                        Energy and Mineral Resources            HSII06
# 1                        Energy and Mineral Resources            HSII06
# 2                        Energy and Mineral Resources            HSII06
# 3                                       Federal Lands            HSII10
# 11  Companies involved in the production of pharma...  0.660035
# 12  Companies involved in the production of pharma...  0.660035
# 13  Companies involved in the production of pharma...  0.660035
# 14  Companies involved in the production of pharma...  0.660035
# 15  Companies involved in the production of pharma...  0.633902
# 16  Companies involved in the production of pharma...  0.633902
# 17  Companies involved in the production of pharma...  0.633902
# 18  Companies involved in the production of pharma...  0.633902
# 19  Companies involved in the production of pharma...  0.633902

# %%
industry_plus_committees = industry_plus_committees.rename(columns = {0: 'BERT Transformer Semantic Context Similarity Score',
                                                                        'asset_description': 'Asset Description',
                                                                        'disclosure_date': 'Disclosure Date',
                                                                        'transaction_date': 'Transaction Date',
                                                                        'industry': 'Industry'
                                                                        })
industry_plus_committees_sorted = industry_plus_committees[['Member',
                                                              'Asset Description',
                                                              'Transaction Date',
                                                              'Disclosure Date',
                                                              'Industry',
                                                              'Subcommittee',
                                                              'BERT Transformer Semantic Context Similarity Score']].drop_duplicates()
industry_plus_committees_sorted = industry_plus_committees_sorted.sort_values('BERT Transformer Semantic Context Similarity Score', ascending = False)
industry_plus_committees_sorted
# Out:
#        Member             Asset Description Transaction Date Disclosure Date  \
# 0   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 8   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 14  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 13  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 12  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 11  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 1   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 9   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 10  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 7   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 6   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 5   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 4   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 3   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 2   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 15  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 16  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 17  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 18  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 19  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
#
#                              Industry  \
# 0   Pharmaceuticals and Biotechnology
# 8   Pharmaceuticals and Biotechnology
# 14  Pharmaceuticals and Biotechnology
# 13  Pharmaceuticals and Biotechnology
# 12  Pharmaceuticals and Biotechnology
# 11  Pharmaceuticals and Biotechnology
# 1   Pharmaceuticals and Biotechnology
# 9   Pharmaceuticals and Biotechnology
# 10  Pharmaceuticals and Biotechnology
# 7   Pharmaceuticals and Biotechnology
# 6   Pharmaceuticals and Biotechnology
# 5   Pharmaceuticals and Biotechnology
# 4   Pharmaceuticals and Biotechnology
# 3   Pharmaceuticals and Biotechnology
# 2   Pharmaceuticals and Biotechnology
# 15  Pharmaceuticals and Biotechnology
# 16  Pharmaceuticals and Biotechnology
# 17  Pharmaceuticals and Biotechnology
# 18  Pharmaceuticals and Biotechnology
# 19  Pharmaceuticals and Biotechnology
#
#                                          Subcommittee  \
# 0                        Energy and Mineral Resources
# 8                       Water, Wildlife and Fisheries
# 14                       Oversight and Investigations
# 13                       Oversight and Investigations
# 12                       Oversight and Investigations
# 11                         Indian and Insular Affairs
# 1                        Energy and Mineral Resources
# 9                          Indian and Insular Affairs
# 10                         Indian and Insular Affairs
# 7                       Water, Wildlife and Fisheries
# 6                       Water, Wildlife and Fisheries
# 5                                       Federal Lands
# 4                                       Federal Lands
# 3                                       Federal Lands
# 2                        Energy and Mineral Resources
# 15  Agriculture, Rural Development, Food and Drug ...
# 16  Agriculture, Rural Development, Food and Drug ...
# 17  Agriculture, Rural Development, Food and Drug ...
# 18   Commerce, Justice, Science, and Related Agencies
# 19   Commerce, Justice, Science, and Related Agencies
#
#     BERT Transformer Semantic Context Similarity Score
# 0                                            0.660035
# 8                                            0.660035
# 14                                           0.660035
# 13                                           0.660035
# 12                                           0.660035
# 11                                           0.660035
# 1                                            0.660035
# 9                                            0.660035
# 10                                           0.660035
# 7                                            0.660035
# 6                                            0.660035
# 5                                            0.660035
# 4                                            0.660035
# 3                                            0.660035
# 2                                            0.660035
# 15                                           0.633902
# 16                                           0.633902
# 17                                           0.633902
# 18                                           0.633902
# 19                                           0.633902

# %% [markdown]
# ### Now, correlate the Industry with the Sub-Committees

# %%
industry_plus_scommittees = correlate(transactions_link_committees.head(30), 'industry_description', 'subcommittee_description')
industry_plus_scommittees
# Out:
# <ipython-input-131-cae931bd611c>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col1] = df[col1].astype(str)
# <ipython-input-131-cae931bd611c>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col2] = df[col2].astype(str)
#     index     Member disclosure_date transaction_date  owner ticker  \
# 0       0  susie lee      2020-04-28       2020-02-24  joint    BHC
# 1       1  susie lee      2020-02-25       2020-01-06  joint    BHC
# 2       2  susie lee      2020-10-07       2020-08-27  joint    BHC
# 3       3  susie lee      2020-04-28       2020-02-24  joint    BHC
# 4       4  susie lee      2020-02-25       2020-01-06  joint    BHC
# 5       5  susie lee      2020-10-07       2020-08-27  joint    BHC
# 6       6  susie lee      2020-04-28       2020-02-24  joint    BHC
# 7       7  susie lee      2020-02-25       2020-01-06  joint    BHC
# 8       8  susie lee      2020-10-07       2020-08-27  joint    BHC
# 9       9  susie lee      2020-04-28       2020-02-24  joint    BHC
# 10     10  susie lee      2020-02-25       2020-01-06  joint    BHC
# 11     11  susie lee      2020-10-07       2020-08-27  joint    BHC
# 12     12  susie lee      2020-04-28       2020-02-24  joint    BHC
# 13     13  susie lee      2020-02-25       2020-01-06  joint    BHC
# 14     14  susie lee      2020-10-07       2020-08-27  joint    BHC
# 15     15  susie lee      2020-04-28       2020-02-24  joint    BHC
# 16     16  susie lee      2020-02-25       2020-01-06  joint    BHC
# 17     17  susie lee      2020-10-07       2020-08-27  joint    BHC
# 18     18  susie lee      2020-04-28       2020-02-24  joint    BHC
# 19     19  susie lee      2020-02-25       2020-01-06  joint    BHC
# 20     20  susie lee      2020-10-07       2020-08-27  joint    BHC
# 21     21  susie lee      2020-04-28       2020-02-24  joint    BHC
# 22     22  susie lee      2020-02-25       2020-01-06  joint    BHC
# 23     23  susie lee      2020-10-07       2020-08-27  joint    BHC
# 24     24  susie lee      2020-04-28       2020-02-24  joint    BHC
# 25     25  susie lee      2020-02-25       2020-01-06  joint    BHC
# 26     26  susie lee      2020-10-07       2020-08-27  joint    BHC
# 27     27  susie lee      2020-04-28       2020-02-24  joint    BHC
# 28     28  susie lee      2020-02-25       2020-01-06  joint    BHC
# 29     29  susie lee      2020-10-07       2020-08-27  joint    BHC
#
#                asset_description       type            amount  \
# 0   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 1   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 2   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 3   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 4   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 5   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 6   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 7   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 8   Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 9   Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 10  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 11  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 12  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 13  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 14  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 15  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 16  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 17  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 18  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 19  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
# 20  Bausch Health Companies Inc.  sale_full  $1,001 - $15,000
# 21  Bausch Health Companies Inc.   purchase  $1,001 - $15,000
#
# 11  Companies involved in the production of pharma...  0.636959
# 12  Companies involved in the production of pharma...  0.573802
# 13  Companies involved in the production of pharma...  0.573802
# 14  Companies involved in the production of pharma...  0.573802
# 15  Companies involved in the production of pharma...  0.703555
# 16  Companies involved in the production of pharma...  0.703555
# 17  Companies involved in the production of pharma...  0.703555
# 18  Companies involved in the production of pharma...  0.652289
# 19  Companies involved in the production of pharma...  0.652289
# 20  Companies involved in the production of pharma...  0.652289
# 21  Companies involved in the production of pharma...  0.643498
# 22  Companies involved in the production of pharma...  0.643498
# 23  Companies involved in the production of pharma...  0.643498
# 24  Companies involved in the production of pharma...  0.688917
# 25  Companies involved in the production of pharma...  0.688917
# 26  Companies involved in the production of pharma...  0.688917
# 27  Companies involved in the production of pharma...  0.642434
# 28  Companies involved in the production of pharma...  0.642434
# 29  Companies involved in the production of pharma...  0.642434

# %%
industry_plus_scommittees = industry_plus_scommittees.rename(columns = {0: 'BERT Transformer Semantic Context Similarity Score',
                                                                        'asset_description': 'Asset Description',
                                                                        'disclosure_date': 'Disclosure Date',
                                                                        'transaction_date': 'Transaction Date',
                                                                        'industry': 'Industry'
                                                                        })
industry_plus_scommittees_sorted = industry_plus_scommittees[['Member',
                                                              'Asset Description',
                                                              'Transaction Date',
                                                              'Disclosure Date',
                                                              'Industry',
                                                              'Subcommittee',
                                                              'BERT Transformer Semantic Context Similarity Score']].drop_duplicates().sort_values('BERT Transformer Semantic Context Similarity Score', ascending = False)
industry_plus_scommittees_sorted
# Out:
#        Member             Asset Description Transaction Date Disclosure Date  \
# 15  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 17  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 16  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 1   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 0   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 2   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 26  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 25  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 24  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 7   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 8   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 6   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 20  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 19  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 18  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 3   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 5   susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 4   susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 21  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 22  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 23  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 27  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 28  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 29  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 11  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 10  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 9   susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
# 14  susie lee  Bausch Health Companies Inc.       2020-08-27      2020-10-07
# 13  susie lee  Bausch Health Companies Inc.       2020-01-06      2020-02-25
# 12  susie lee  Bausch Health Companies Inc.       2020-02-24      2020-04-28
#
#                              Industry  \
# 15  Pharmaceuticals and Biotechnology
# 17  Pharmaceuticals and Biotechnology
# 16  Pharmaceuticals and Biotechnology
# 1   Pharmaceuticals and Biotechnology
# 0   Pharmaceuticals and Biotechnology
# 2   Pharmaceuticals and Biotechnology
# 26  Pharmaceuticals and Biotechnology
# 25  Pharmaceuticals and Biotechnology
# 24  Pharmaceuticals and Biotechnology
# 7   Pharmaceuticals and Biotechnology
# 8   Pharmaceuticals and Biotechnology
# 6   Pharmaceuticals and Biotechnology
# 20  Pharmaceuticals and Biotechnology
# 19  Pharmaceuticals and Biotechnology
# 18  Pharmaceuticals and Biotechnology
# 3   Pharmaceuticals and Biotechnology
# 5   Pharmaceuticals and Biotechnology
# 4   Pharmaceuticals and Biotechnology
# 21  Pharmaceuticals and Biotechnology
# 22  Pharmaceuticals and Biotechnology
# 23  Pharmaceuticals and Biotechnology
# 27  Pharmaceuticals and Biotechnology
# 28  Pharmaceuticals and Biotechnology
# 29  Pharmaceuticals and Biotechnology
# 11  Pharmaceuticals and Biotechnology
# 10  Pharmaceuticals and Biotechnology
# 9   Pharmaceuticals and Biotechnology
# 11  Pharmaceuticals and Biotechnology
# 9   Pharmaceuticals and Biotechnology
# 10  Pharmaceuticals and Biotechnology
# 12  Pharmaceuticals and Biotechnology
# 13  Pharmaceuticals and Biotechnology
# 14  Pharmaceuticals and Biotechnology
#
#                                          Subcommittee  \
# 17  Agriculture, Rural Development, Food and Drug ...
# 16  Agriculture, Rural Development, Food and Drug ...
# 15  Agriculture, Rural Development, Food and Drug ...
# 0                        Energy and Mineral Resources
# 1                        Energy and Mineral Resources
# 2                        Energy and Mineral Resources
# 6                       Water, Wildlife and Fisheries
# 7                       Water, Wildlife and Fisheries
# 8                       Water, Wildlife and Fisheries
# 18   Commerce, Justice, Science, and Related Agencies
# 19   Commerce, Justice, Science, and Related Agencies
# 5                                       Federal Lands
# 4                                       Federal Lands
# 3                                       Federal Lands
# 11                         Indian and Insular Affairs
# 9                          Indian and Insular Affairs
# 10                         Indian and Insular Affairs
# 12                       Oversight and Investigations
# 13                       Oversight and Investigations
# 14                       Oversight and Investigations
#
#     BERT Transformer Semantic Context Similarity Score
# 17                                           0.703555
# 16                                           0.703555
# 15                                           0.703555
# 0                                            0.699247
# 1                                            0.699247
# 2                                            0.699247
# 6                                            0.674148
# 7                                            0.674148
# 8                                            0.674148
# 18                                           0.652289
# 19                                           0.652289
# 5                                            0.648826
# 4                                            0.648826
# 3                                            0.648826
# 11                                           0.636959
# 9                                            0.636959
# 10                                           0.636959
# 12                                           0.573802
# 13                                           0.573802
# 14                                           0.573802

# %% [markdown]
# # Transactions Link to Bills

# %% [markdown]
# # Transactions Link to Statements

# %%
text_source_1 = "Text one is sad"
text_source_2 = "Text two is quite enlightened by the current circumstances"
text_source_3 = "Text three likes"
query = "Text one is happy"


# Load a pre-trained model and tokenizer
model_name = "bert-base-uncased"  # You can change the model as needed
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Tokenize the text data
input_ids_1 = tokenizer(text_source_1, return_tensors="pt")['input_ids']
input_ids_2 = tokenizer(text_source_2, return_tensors="pt")['input_ids']
input_ids_3 = tokenizer(text_source_3, return_tensors="pt")['input_ids']

# Get embeddings for the text data
with torch.no_grad():
    embeddings_1 = model(input_ids_1)['last_hidden_state'].mean(dim=1).numpy()
    embeddings_2 = model(input_ids_2)['last_hidden_state'].mean(dim=1).numpy()
    embeddings_3 = model(input_ids_3)['last_hidden_state'].mean(dim=1).numpy()

# Calculate cosine similarity for semantic similarity
similarity_1_2 = cosine_similarity(embeddings_1, embeddings_2)[0][0]
similarity_1_3 = cosine_similarity(embeddings_1, embeddings_3)[0][0]
similarity_2_3 = cosine_similarity(embeddings_2, embeddings_3)[0][0]

print(f"Semantic Similarity between Source 1 and Source 2: {similarity_1_2:.4f}")
print(f"Semantic Similarity between Source 1 and Source 3: {similarity_1_3:.4f}")
print(f"Semantic Similarity between Source 2 and Source 3: {similarity_2_3:.4f}")
# Out:
# Semantic Similarity between Source 1 and Source 2: 0.6033
# Semantic Similarity between Source 1 and Source 3: 0.7766
# Semantic Similarity between Source 2 and Source 3: 0.4765
