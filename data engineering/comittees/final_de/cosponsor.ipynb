# %%
import pandas as pd
import nameparser
import json
import requests
import numpy as np

pro_publica_api_key = "PguHImFJakafbsBpZ2ed21A1HIgvXKiM7tg0BqI0 "
headers = {'X-API-Key': pro_publica_api_key}
# Out:
# /Users/mats_dodd/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
members = pd.read_csv('../prod_data/transactions.csv')
member_ids = members['id'].unique()

member_ids
# Out:
# array(['L000590', 'L000579', 'B001274', 'W000804', 'D000617', 'G000584',
#        'S001199', 'B000574', 'C001108', 'F000462', 'L000559', 'G000583',
#        'M001157', 'M001180', 'P000197', 'C001068', 'C001078', 'D000399',
#        'M001185', 'S000185', 'J000020', 'L000576', 'C001114', 'M001188',
#        'A000372', 'B001299', 'D000624', 'D000628', 'U000031', 'L000564',
#        'V000108', 'H001065', 'E000296', 'R000607', 'P000616', 'W000800',
#        'J000294', nan, 'C001123', 'C001062', 'L000397', 'B001286',
#        'M001199', 'Y000062', 'S001180', 'G000590', 'R000609', 'B001292',
#        'H001082', 'S001190', 'G000588', 'H001074', 'R000597', 'G000563',
#        'H001038', 'D000598', 'G000061', 'F000450', 'C001101', 'P000523',
#        'T000479', 'K000392', 'C001069', 'S001207', 'P000593', 'M001198',
#        'G000551', 'S001216', 'C001049', 'A000378', 'S001214', 'F000459',
#        'G000579', 'J000295', 'W000797', 'C001066', 'C001120', 'G000591',
# ...

# %%
member_id = member_ids[10]

url = f'https://api.propublica.org/congress/v1/members/{member_id}/bills/cosponsored.json'
r = requests.get(url, headers=headers)
r.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 Pro Publica Inc. All Rights Reserved.',
#  'results': [{'id': 'L000559',
#    'member_uri': 'https://api.propublica.org/congress/v1/members/L000559.json',
#    'name': 'Jim Langevin',
#    'num_results': 4053,
#    'offset': 0,
#    'bills': [{'congress': '117',
#      'bill_id': 'hr3402-117',
#      'bill_type': 'hr',
#      'number': 'H.R.3402',
#      'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr3402.json',
#      'title': 'To amend title 38, United States Code, to improve and to expand eligibility for dependency and indemnity compensation paid to certain survivors of certain veterans, and for other purposes.',
#      'short_title': 'Caring for Survivors Act of 2021',
#      'sponsor_title': '',
#      'sponsor_id': 'H001081',
#      'sponsor_name': 'Jahana Hayes',
#      'sponsor_state': 'CT',
#      'sponsor_party': 'D',
#      'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H001081.json',
# ...

# %%
member_id
# Out:
# 'L000559'
